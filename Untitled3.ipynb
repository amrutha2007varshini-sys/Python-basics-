# %% [markdown]
# <a href="https://colab.research.google.com/github/amrutha2007varshini-sys/Python-basics-/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
age = int(input("Enter your age: "))

if age < 18:
    print("Not eligible for voting")
else:
    print("Eligible for voting")
# Out:
# Enter your age: 19
# Eligible for voting

# %%
marks = int(input("Enter student marks: "))

if marks >= 50:
    print("Student is Pass")
else:
    marks = marks + 10
    print("10 grace marks added")

    if marks >= 50:
        print("Student is Pass after grace marks added")
    else:
        print("Student is Fail")
# Out:
# Enter student marks: 45
# 10 grace marks added
# Student is Pass after grace marks added
